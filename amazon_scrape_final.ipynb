# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
###Function to extract Product Title

def get_title(soup):

    try:
        #Outer tag object
        title=soup.find("span",attrs={"id":'productTitle'})

        #Inner NavigatableString Object
        title_value = title.text

        #Title as a string value
        title_string=title_value.strip()


    except AttributeError:
        title_string = ""

    return title_string

#Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span",attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            #If there is some deal price
            price = soup.find("span",attrs={'id':'priceblock_dealprice'}).string.strip()
        except:
            price=""
    return price

#Function to extract Product Rating
def get_rating(soup):
    try:
        rating = soup.find("i",attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span",attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating=""
    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span",attrs={'id':'acrCustomerReviewText'}).string.strip()
    except AttributeError:
        review_count=""
    
    return review_count

#Function to extract Availability Status
def get_availablity(soup):
    try:
        available = soup.find("div",attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"
    
    return available

# %%
if __name__=='__main__':

    #add your user agent
    HEADERS = ({'User-Agent':'','Accept-Language': 'en-US, en;q=0.5'})

    # The Webpage URL
    URL = "https://www.amazon.in/s?k=earbuds&i=electronics&sprefix=ear%2Celectronics%2C333&ref=nb_sb_ss_ts-doa-p_1_3"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    #Soup Object Conatining all data
    soup = BeautifulSoup(webpage.content,"html.parser")

    #Fetch links as list of Tag Object
    links = soup.find_all("a",attrs={'class':"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"})

    #Store the links
    links_list=[]

    #Loop for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
    
    d = {'title':[],'price':[],'rating':[],'reviews':[],'availablity':[]}

    #Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in/" + link,headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content,"html.parser")

        #Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availablity'].append(get_availablity(new_soup))

amazon_df = pd.DataFrame.from_dict(d)
amazon_df['title'].replace('',np.nan,inplace=True)
amazon_df = amazon_df.dropna(subset=['title'])
amazon_df.to_csv('amazon_data.csv',header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0   boAt Airdopes 141 Bluetooth Truly Wireless in ...
# 1   Amazon Basics Bluetooth 5.0 Truly Wireless in ...
# 2   AmazonBasics Truly Wireless in Ear Earbuds wit...
# 3   boAt Airdopes 141 Bluetooth Truly Wireless in ...
# 4   OnePlus Nord Buds 2 True Wireless in Ear Earbu...
# 5   OnePlus Nord Buds True Wireless in Ear Earbuds...
# 6   OnePlus Nord Buds True Wireless in Ear Earbuds...
# 7   Sony WF-C500 Truly Wireless Bluetooth Earbuds ...
# 8   OnePlus Nord Buds True Wireless in Ear Earbuds...
# 9   OnePlus Buds Z2 Bluetooth Truly Wireless in Ea...
# 10  OnePlus Bullets Z2 Bluetooth Wireless in Ear E...
# 11  boAt BassHeads 100 in-Ear Wired Headphones wit...
# 12  JBL C100SI Wired In Ear Headphones with Mic, J...
# 13  boAt Bassheads 100 in Ear Wired Earphones with...
# 14  boAt Airdopes 121v2 in-Ear True Wireless Earbu...
# 15  boAt Airdopes Atom 81 True Wireless Earbuds wi...
# 16  OnePlus Nord Buds True Wireless in Ear Earbuds...
# 17  realme Buds Air 3 Neo True Wireless in-Ear Ear...
# 18  JBL Wave 200 True Wireless In Ear Earbuds with...
# 19  boAt Airdopes 141 Bluetooth Truly Wireless in ...
# 20  Boult Audio Z40 True Wireless in Ear Earbuds w...
# 21  TOZO T6 True Wireless Earbuds Bluetooth 5.3 He...
# 22  truke Newly Launched Buds Vibe True Wireless i...
# 23  Samsung Galaxy Buds 2 | Wireless in Ear Earbud...
# 24  Sony WF-C500 Truly Wireless Bluetooth Earbuds ...
# 25  realme TechLife Buds T100 Bluetooth Truly Wire...
# 26  Noise Buds VS104 in-Ear Truly Wireless Earbuds...
# 27  TOZO T6 True Wireless Earbuds Bluetooth 5.3 He...
# 28  pTron Bassbuds Duo in Ear Earbuds with 32Hrs T...
# 29  Oppo Enco Buds Bluetooth True Wireless in Ear ...
# 30  Boult Audio Z20 True Wireless in Ear Earbuds w...
# 31  Boult Audio Z40 True Wireless in Ear Earbuds w...
# 32  pTron Bassbuds Duo in Ear Earbuds with 32Hrs T...
# 33  Boult Audio Z20 True Wireless in Ear Earbuds w...
# 34  ZEBRONICS PODS 2 Wireless TWS Earbuds with Blu...
# 35  Noise Buds VS104 in-Ear Truly Wireless Earbuds...
# 36  boAt Airdopes 141 Bluetooth Truly Wireless in ...
# 37  Noise Buds Ace Truly Wireless Half in-Ear Earb...
# 38  truke Buds S2 Lite True Wireless in Ear Earbud...
# 39  pTron Bassbuds Duo in Ear Earbuds with 32Hrs T...
# 40  truke Buds BTG 1 Bluetooth Truly Wireless Gami...
#
#                 rating          reviews                    availablity
# 0   3.9 out of 5 stars  183,963 ratings                       In stock
# 1   3.3 out of 5 stars    1,566 ratings                       In stock
# 2   3.7 out of 5 stars    1,065 ratings                       In stock
# 3   3.9 out of 5 stars  183,963 ratings                       In stock
# 4   4.2 out of 5 stars   32,868 ratings                       In stock
# 5   4.2 out of 5 stars   32,868 ratings                       In stock
# 6   4.2 out of 5 stars   32,868 ratings                       In stock
# 7   4.1 out of 5 stars    6,393 ratings                       In stock
# 8   4.2 out of 5 stars   32,868 ratings                       In stock
# 9   4.2 out of 5 stars   18,432 ratings                       In stock
# 10  4.2 out of 5 stars  102,108 ratings                       In stock
# 11  4.1 out of 5 stars  384,486 ratings                       In stock
# 12  4.1 out of 5 stars  196,460 ratings                       In stock
# 13  4.1 out of 5 stars  384,486 ratings                       In stock
# 14  3.8 out of 5 stars  192,187 ratings                       In stock
# 15  3.7 out of 5 stars    5,979 ratings  Available to ship in 1-2 days
# 16  4.2 out of 5 stars   32,868 ratings                       In stock
# 17  4.0 out of 5 stars    7,977 ratings                       In stock
# 18  3.6 out of 5 stars    7,973 ratings                       In stock
# 19  3.9 out of 5 stars  183,963 ratings                       In stock
# 20  3.9 out of 5 stars    3,005 ratings                       In stock
# 21  4.4 out of 5 stars  210,530 ratings                       In stock
# 22  4.2 out of 5 stars      525 ratings                       In stock
# 23  4.2 out of 5 stars      842 ratings                       In stock
# 24  4.1 out of 5 stars    6,393 ratings                       In stock
# 25  4.0 out of 5 stars    7,349 ratings                       In stock
# 26  3.9 out of 5 stars   15,759 ratings                       In stock
# 27  4.4 out of 5 stars  210,530 ratings                       In stock
# 28  3.5 out of 5 stars  172,078 ratings                       In stock
# 29  4.0 out of 5 stars   21,697 ratings                       In stock
# 30  3.8 out of 5 stars   12,917 ratings                       In stock
# 31  3.9 out of 5 stars    3,005 ratings                       In stock
# 32  3.5 out of 5 stars  172,078 ratings                       In stock
# 33  3.8 out of 5 stars   12,917 ratings                       In stock
# 34  3.7 out of 5 stars      188 ratings                       In stock
# 35  3.9 out of 5 stars   15,759 ratings                       In stock
# 36  3.9 out of 5 stars  183,963 ratings                       In stock
# 37  3.6 out of 5 stars       58 ratings                       In stock
# 38  3.9 out of 5 stars    1,801 ratings                       In stock
# 39  3.5 out of 5 stars  172,078 ratings                       In stock
# 40  3.9 out of 5 stars    2,349 ratings                       In stock
